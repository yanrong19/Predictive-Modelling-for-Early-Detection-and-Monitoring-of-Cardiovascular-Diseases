# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load dataset
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#data structure
print(df.shape)
print(df.columns)
# Out:
# (918, 12)
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
#describe data
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# None
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# ...

# %%
#check missing values
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# <h3>Distribution of Variables in Dataset</h3>

# %%
#Age
sns.histplot(data=df, x="Age", bins=15).set(title="Histogram of Age")
# Out:
# [Text(0.5, 1.0, 'Histogram of Age')]

# %%
sns.boxplot(x = 'Age', data = df).set(title="Boxplot of Age")
# Out:
# [Text(0.5, 1.0, 'Boxplot of Age')]

# %%
df["Age"].describe()
# Out:
# count    918.000000
# mean      53.510893
# std        9.432617
# min       28.000000
# 25%       47.000000
# 50%       54.000000
# 75%       60.000000
# max       77.000000
# Name: Age, dtype: float64

# %%
#Sex
xticks = ["Male", "Female"]
sns.countplot(x='Sex', data=df).set(title="Barplot of Sex")
plt.xticks([0,1], xticks)
plt.show()

# %%
df["Sex"].describe()
# Out:
# count     918
# unique      2
# top         M
# freq      725
# Name: Sex, dtype: object

# %%
#Chest Pain Type
sns.countplot(x='ChestPainType', data=df).set(title="Barplot of Chest Pain Type")

# %%
df["ChestPainType"].describe()
# Out:
# count     918
# unique      4
# top       ASY
# freq      496
# Name: ChestPainType, dtype: object

# %%
#RestingBP
sns.histplot(data=df, x="RestingBP", bins=15).set(title="Histogram of Resting BP")
# Out:
# [Text(0.5, 1.0, 'Histogram of Resting BP')]

# %%
sns.boxplot(x = 'RestingBP', data = df).set(title="Boxplot of Resting BP")
# Out:
# [Text(0.5, 1.0, 'Boxplot of Resting BP')]

# %%
df["RestingBP"].describe()
# Out:
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64

# %%
#Cholesterol
sns.histplot(data=df, x="Cholesterol", bins=15).set(title="Histogram of Cholesterol")
# Out:
# [Text(0.5, 1.0, 'Histogram of Cholesterol')]

# %%
sns.boxplot(x = 'Cholesterol', data = df).set(title="Boxplot of Cholesterol")
# Out:
# [Text(0.5, 1.0, 'Boxplot of Cholesterol')]

# %%
df["Cholesterol"].describe()
# Out:
# count    918.000000
# mean     198.799564
# std      109.384145
# min        0.000000
# 25%      173.250000
# 50%      223.000000
# 75%      267.000000
# max      603.000000
# Name: Cholesterol, dtype: float64

# %%
df = df[df["Cholesterol"] > 0]

# %%
#FastingBS
sns.countplot(x='FastingBS', data=df).set(title="Barplot of Fasting Blood Sugar")
# Out:
# [Text(0.5, 1.0, 'Barplot of Fasting Blood Sugar')]

# %%
df['FastingBS'].astype(bool).describe()
# Out:
# count       918
# unique        2
# top       False
# freq        704
# Name: FastingBS, dtype: object

# %%
#RestingECG
sns.countplot(x='RestingECG', data=df).set(title="Barplot of Resting ECG Results")
# Out:
# [Text(0.5, 1.0, 'Barplot of Resting ECG Results')]

# %%
df["RestingECG"].describe()
# Out:
# count        918
# unique         3
# top       Normal
# freq         552
# Name: RestingECG, dtype: object

# %%
#MaxHR
sns.histplot(data=df, x="MaxHR", bins=15).set(title="Histogram of Maximum Heart Rate Achieved")
# Out:
# [Text(0.5, 1.0, 'Histogram of Maximum Heart Rate Achieved')]

# %%
sns.boxplot(x = "MaxHR", data = df).set(title="Boxplot of Maximum Heart Rate Achieved")
# Out:
# [Text(0.5, 1.0, 'Boxplot of Maximum Heart Rate Achieved')]

# %%
df["MaxHR"].describe()
# Out:
# count    918.000000
# mean     136.809368
# std       25.460334
# min       60.000000
# 25%      120.000000
# 50%      138.000000
# 75%      156.000000
# max      202.000000
# Name: MaxHR, dtype: float64

# %%
#ExerciseAngina
sns.countplot(x='ExerciseAngina', data=df).set(title="Barplot of Exercise-Induced Angina")
# Out:
# [Text(0.5, 1.0, 'Barplot of Exercise-Induced Angina')]

# %%
df['ExerciseAngina'].describe()
# Out:
# count     918
# unique      2
# top         N
# freq      547
# Name: ExerciseAngina, dtype: object

# %%
#Oldpeak
sns.histplot(data=df, x="Oldpeak", bins=15).set(title="Histogram of Oldpeak")
# Out:
# [Text(0.5, 1.0, 'Histogram of Oldpeak')]

# %%
sns.boxplot(x = 'Oldpeak', data = df).set(title="Boxplot of Oldpeak")
# Out:
# [Text(0.5, 1.0, 'Boxplot of Oldpeak')]

# %%
df['Oldpeak'].describe()
# Out:
# count    918.000000
# mean       0.887364
# std        1.066570
# min       -2.600000
# 25%        0.000000
# 50%        0.600000
# 75%        1.500000
# max        6.200000
# Name: Oldpeak, dtype: float64

# %%
#ST_Slope
sns.countplot(x='ST_Slope', data=df).set(title="Barplot of Slope of Peak Exercise ST Segment")
# Out:
# [Text(0.5, 1.0, 'Barplot of Slope of Peak Exercise ST Segment')]

# %%
df['ST_Slope'].describe()
# Out:
# count      918
# unique       3
# top       Flat
# freq       460
# Name: ST_Slope, dtype: object

# %%
#HeartDisease (Target Variable)
sns.countplot(x='HeartDisease', data=df).set(title="Barplot of Heart Disease Outcome")
# Out:
# [Text(0.5, 1.0, 'Barplot of Heart Disease Outcome')]

# %%
df['HeartDisease'].describe()
# Out:
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: HeartDisease, dtype: float64

# %%
#Correlation between continuous feature variables
cont_feat_var = ["Age","RestingBP","Cholesterol","MaxHR","Oldpeak"]
sns.heatmap(df[cont_feat_var].corr()).set(title="Heatmap for Correlation between Continuous Feature Variables")
plt.show()

# %%
#pairwise scatterplot between continuous variables
pd.plotting.scatter_matrix(df[cont_feat_var])
plt.suptitle('Pairwise Scatterplot of Continuous Feature Variables', fontsize=16)
plt.show()

# %%
#One-hot encoding
df["Sex_M"] = np.where(df["Sex"]=="M",1,0)

df["ChestPainType_TA"] = np.where(df["ChestPainType"]=="TA",1,0)
df["ChestPainType_ATA"] = np.where(df["ChestPainType"]=="ATA",1,0)
df["ChestPainType_NAP"] = np.where(df["ChestPainType"]=="NAP",1,0)

df["RestingECG_N"] = np.where(df["RestingECG"]=="Normal",1,0)
df["RestingECG_ST"] = np.where(df["RestingECG"]=="ST",1,0)

df["ExerciseAngina_Y"] = np.where(df["ExerciseAngina"]=="Y",1,0)

df["ST_Slope_U"] = np.where(df["ST_Slope"]=="Up",1,0)
df["ST_Slope_F"] = np.where(df["ST_Slope"]=="Flat",1,0)

var = cont_feat_var + ["Sex_M","ChestPainType_TA","ChestPainType_ATA","ChestPainType_NAP",
                       "RestingECG_N","RestingECG_ST","ExerciseAngina_Y","ST_Slope_U","ST_Slope_F"]
df2 = df[var]

# %%
df2
# Out:
#      Age  RestingBP  Cholesterol  MaxHR  Oldpeak  Sex_M  ChestPainType_TA  \
# 0     40        140          289    172      0.0      1                 0
# 1     49        160          180    156      1.0      0                 0
# 2     37        130          283     98      0.0      1                 0
# 3     48        138          214    108      1.5      0                 0
# 4     54        150          195    122      0.0      1                 0
# ..   ...        ...          ...    ...      ...    ...               ...
# 913   45        110          264    132      1.2      1                 1
# 914   68        144          193    141      3.4      1                 0
# 915   57        130          131    115      1.2      1                 0
# 916   57        130          236    174      0.0      0                 0
# 917   38        138          175    173      0.0      1                 0
#
#      ChestPainType_ATA  ChestPainType_NAP  RestingECG_N  RestingECG_ST  \
# ...

# %% [markdown]
# <h3>Principal Component Analysis</h3>

# %%
#Standardization
##Standardise Function
def standardise(df, columns):
    new_df = df.copy(deep=True)
    for col in columns:
        new_df[col] = (df[col] - df[col].mean()) / df[col].std()
    return new_df

# %%
df3 = standardise(df2, var)
df3
# Out:
#           Age  RestingBP  Cholesterol     MaxHR   Oldpeak     Sex_M  \
# 0   -1.432359   0.410685     0.824621  1.382175 -0.831979  0.515671
# 1   -0.478223   1.490940    -0.171867  0.753746  0.105606 -1.937107
# 2   -1.750404  -0.129442     0.769768 -1.524307 -0.831979  0.515671
# 3   -0.584238   0.302660     0.138964 -1.131539  0.574398 -1.937107
# 4    0.051853   0.950812    -0.034736 -0.581664 -0.831979  0.515671
# ..        ...        ...          ...       ...       ...       ...
# 913 -0.902283  -1.209697     0.596068 -0.188897  0.293123  0.515671
# 914  1.536064   0.626736    -0.053020  0.164595  2.355810  0.515671
# 915  0.369898  -0.129442    -0.619830 -0.856602  0.293123  0.515671
# 916  0.369898  -0.129442     0.340090  1.460728 -0.831979 -1.937107
# 917 -1.644389   0.302660    -0.217578  1.421452 -0.831979  0.515671
#
#      ChestPainType_TA  ChestPainType_ATA  ChestPainType_NAP  RestingECG_N  \
# 0           -0.229554           2.074046          -0.532547      0.813831
# ...

# %% [markdown]
# ## Principal Component Analysis

# %%
attributeNames = df3.columns
# Extract class names to python list,
# then encode with integers (dict)
classLabels = list(df["HeartDisease"])
classNames = sorted(set(classLabels))
classDict = dict(zip(classNames, range(2)))

# Extract vector y, convert to NumPy array
y = np.asarray([classDict[value] for value in classLabels])

# Preallocate memory, then extract excel data to matrix X
X = np.asarray(df3)

# Compute values of N, M and C.
N = len(y)
M = len(attributeNames)
C = len(classNames)

# %%
# Data attributes to be plotted
i = 0
j = 1

# %%
# Make another more fancy plot that includes legend, class labels, 
# attribute names, and a title.
f = plt.figure()
plt.title('Heart Disease data')

for c in range(C):
    # select indices belonging to class c:
    class_mask = y==c
    plt.plot(X[class_mask,i], X[class_mask,j], 'o',alpha=.3)

plt.legend(classNames)
plt.xlabel(attributeNames[i])
plt.ylabel(attributeNames[j])

# Output result to screen
plt.show()

# %%
from scipy.linalg import svd

X = pd.DataFrame(df3)
# Subtract mean value from data
Y = X - X.mean(axis=0)
# PCA by computing SVD of Y
U,S,V = svd(Y,full_matrices=False)

# Compute variance explained by principal components
rho = (S*S) / (S*S).sum()

threshold = 0.9

# Plot variance explained
plt.figure()
plt.plot(range(1,len(rho)+1),rho,'x-')
plt.plot(range(1,len(rho)+1),np.cumsum(rho),'o-')
plt.plot([1,len(rho)],[threshold, threshold],'k--')
plt.title('Variance explained by principal components');
plt.xlabel('Principal component');
plt.ylabel('Variance explained');
plt.legend(['Individual','Cumulative','Threshold'])
plt.grid()
plt.show()

# %%
Y = X - X.mean(0)

# PCA by computing SVD of Y
U,S,Vh = svd(Y,full_matrices=False)
# scipy.linalg.svd returns "Vh", which is the Hermitian (transpose)
# of the vector V. So, for us to obtain the correct V, we transpose:
V = Vh.T    

# Project the centered data onto principal component space
Z = Y @ V

# Indices of the principal components to be plotted
i = 0
j = 1

# Plot PCA of the data
f = plt.figure()
plt.title('HeartDisease data: PCA')
#Z = array(Z)
for c in range(C):
    # select indices belonging to class c:
    class_mask = y==c
    plt.plot(Z[class_mask,i], Z[class_mask,j], 'o', alpha=.5)
plt.legend(classNames)
plt.xlabel('PC{0}'.format(i+1))
plt.ylabel('PC{0}'.format(j+1))

# Output result to screen
plt.show()

# %%
Y = X - np.ones((N,1))*X.mean(0)
U,S,Vh = svd(Y,full_matrices=False)
V=Vh.T
N,M = X.shape

# We saw in 2.1.3 that the first 3 components explaiend more than 90
# percent of the variance. Let's look at their coefficients:
pcs = [0,1]
legendStrs = ['PC'+str(e+1) for e in pcs]
c = ['r','g','b']
bw = .2
r = np.arange(1,M+1)
for i in pcs:    
    plt.bar(r+i*bw, V[:,i], width=bw)
plt.xticks(r+bw, attributeNames, fontsize=6, rotation=30)
plt.xlabel('Attributes')
plt.ylabel('Component coefficients')
plt.legend(legendStrs)
plt.grid()
plt.title('Heart Disease: PCA Component Coefficients')
plt.show()

# Inspecting the plot, we see that the 2nd principal component has large
# (in magnitude) coefficients for attributes A, E and H. We can confirm
# this by looking at it's numerical values directly, too:
print('PC2:')
print(V[:,1].T)
print("\n")

print('Patient with normal ECG (positive value for RestingECG_N and negative value for RestingECG_ST)')
print(Y[0,:])
print('...and its projection onto PC2')
print(Y[0,:]@V[:,1])
print("\n")
print('Patient with ST ECG (negative value for RestingECG_N and positive value for RestingECG_ST)')
print(Y[2,:])
print('...and its projection onto PC2')
print(Y[2,:]@V[:,1])
# Try to explain why?
# Out:
# PC2:
# [ 0.21393113  0.19398884  0.00238733  0.02493241 -0.03364273 -0.05464801
#   0.0904244   0.05560666 -0.0052394  -0.64252912  0.61787847 -0.08939433
#   0.21190349 -0.23032197]
#
#
# Patient with normal ECG (positive value for RestingECG_N and negative value for RestingECG_ST)
# [-1.43235901  0.41068502  0.82462075  1.38217478 -0.83197888  0.51567132
#  -0.22955354  2.07404613 -0.53254747  0.81383119 -0.49018212 -0.82310761
#   1.15004709 -1.00163503]
# ...and its projection onto PC2
# -0.3709593987033945
#
#
# Patient with ST ECG (negative value for RestingECG_N and positive value for RestingECG_ST)
# [-1.75040438 -0.12944227  0.7697682  -1.5243071  -0.83197888  0.51567132
#  -0.22955354  2.07404613 -0.53254747 -1.22741754  2.03783579 -0.82310761
#   1.15004709 -1.00163503]
# ...and its projection onto PC2
# 2.25719514804321
